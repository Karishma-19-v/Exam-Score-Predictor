# %%
import pandas as pd
df=pd.read_csv("student_habits_performance.csv")

# %%
df
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
df['student_id']
# Out:
# 0      S1000
# 1      S1001
# 2      S1002
# 3      S1003
# 4      S1004
#        ...
# 995    S1995
# 996    S1996
# 997    S1997
# 998    S1998
# 999    S1999
# Name: student_id, Length: 1000, dtype: object

# %%
df.head()
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
df.shape
# Out:
# (1000, 16)

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'study_hours_per_day',
#        'social_media_hours', 'netflix_hours', 'part_time_job',
#        'attendance_percentage', 'sleep_hours', 'diet_quality',
#        'exercise_frequency', 'parental_education_level', 'internet_quality',
#        'mental_health_rating', 'extracurricular_participation', 'exam_score'],
#       dtype='object')

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
sns.set(style='whitegrid')

# %%
df.isna().sum()
# Out:
# student_id                        0
# age                               0
# gender                            0
# study_hours_per_day               0
# social_media_hours                0
# netflix_hours                     0
# part_time_job                     0
# attendance_percentage             0
# sleep_hours                       0
# diet_quality                      0
# exercise_frequency                0
# parental_education_level         91
# internet_quality                  0
# mental_health_rating              0
# extracurricular_participation     0
# exam_score                        0
# dtype: int64

# %%
df=df.dropna()

# %%
df.isna().sum()
# Out:
# student_id                       0
# age                              0
# gender                           0
# study_hours_per_day              0
# social_media_hours               0
# netflix_hours                    0
# part_time_job                    0
# attendance_percentage            0
# sleep_hours                      0
# diet_quality                     0
# exercise_frequency               0
# parental_education_level         0
# internet_quality                 0
# mental_health_rating             0
# extracurricular_participation    0
# exam_score                       0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 909, dtype: bool

# %%
df.describe(include='object').columns
# Out:
# Index(['student_id', 'gender', 'part_time_job', 'diet_quality',
#        'parental_education_level', 'internet_quality',
#        'extracurricular_participation'],
#       dtype='object')

# %%
categorical_col=['student_id', 'gender', 'part_time_job', 'diet_quality',
       'parental_education_level', 'internet_quality',
       'extracurricular_participation']

# %%
df.describe().columns
# Out:
# Index(['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours',
#        'attendance_percentage', 'sleep_hours', 'exercise_frequency',
#        'mental_health_rating', 'exam_score'],
#       dtype='object')

# %%
num_feature=['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours',
       'attendance_percentage', 'sleep_hours', 'exercise_frequency',
       'mental_health_rating']
# exam_score is target column

# %%
for feature in num_feature:
    sns.scatterplot(data=df, x=feature , y="exam_score")
    plt.title("{feature} vs exam_score")
    plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.7 MB 1.7 MB/s eta 0:00:05
#    ------ --------------------------------- 1.3/8.7 MB 1.9 MB/s eta 0:00:04
#    ------- -------------------------------- 1.6/8.7 MB 2.0 MB/s eta 0:00:04
#    --------- ------------------------------ 2.1/8.7 MB 2.0 MB/s eta 0:00:04
#    ------------ --------------------------- 2.6/8.7 MB 2.0 MB/s eta 0:00:04
#    ------------- -------------------------- 2.9/8.7 MB 1.9 MB/s eta 0:00:04
#    ------------- -------------------------- 2.9/8.7 MB 1.9 MB/s eta 0:00:04
#    ------------- -------------------------- 2.9/8.7 MB 1.9 MB/s eta 0:00:04
#    ------------- -------------------------- 2.9/8.7 MB 1.9 MB/s eta 0:00:04
#    ------------- -------------------------- 2.9/8.7 MB 1.9 MB/s eta 0:00:04
#    -------------- ------------------------- 3.1/8.7 MB 1.2 MB/s eta 0:00:05
# ...

# %%
# now select feature which we are going to use for our model

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'study_hours_per_day',
#        'social_media_hours', 'netflix_hours', 'part_time_job',
#        'attendance_percentage', 'sleep_hours', 'diet_quality',
#        'exercise_frequency', 'parental_education_level', 'internet_quality',
#        'mental_health_rating', 'extracurricular_participation', 'exam_score'],
#       dtype='object')

# %%
df.head(2)
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# 1         Good                   6              High School          Average
#
#    mental_health_rating extracurricular_participation  exam_score
# 0                     8                           Yes        56.2
# 1                     8                            No       100.0

# %%
feature=['study_hours_per_day','attendance_percentage','mental_health_rating','sleep_hours']

# %%
target="exam_score"

# %%
le=LabelEncoder

# %%
df_model=df[feature+[target]].copy()

# %%
df_model
# Out:
#      study_hours_per_day  attendance_percentage  mental_health_rating  \
# 0                    0.0                   85.0                     8
# 1                    6.9                   97.3                     8
# 2                    1.4                   94.8                     1
# 3                    1.0                   71.0                     1
# 4                    5.0                   90.9                     1
# ..                   ...                    ...                   ...
# 995                  2.6                   77.0                     6
# 996                  2.9                   86.0                     6
# 997                  3.0                   61.9                     9
# 998                  5.4                  100.0                     1
# 999                  4.3                   89.4                     8
#
#      sleep_hours  exam_score
# 0            8.0        56.2
# 1            4.6       100.0
# 2            8.0        34.3
# ...

# %%
X=df_model[feature]

# %%
X
# Out:
#      study_hours_per_day  attendance_percentage  mental_health_rating  \
# 0                    0.0                   85.0                     8
# 1                    6.9                   97.3                     8
# 2                    1.4                   94.8                     1
# 3                    1.0                   71.0                     1
# 4                    5.0                   90.9                     1
# ..                   ...                    ...                   ...
# 995                  2.6                   77.0                     6
# 996                  2.9                   86.0                     6
# 997                  3.0                   61.9                     9
# 998                  5.4                  100.0                     1
# 999                  4.3                   89.4                     8
#
#      sleep_hours
# 0            8.0
# 1            4.6
# 2            8.0
# 3            9.2
# 4            4.9
# ...

# %%
y=df_model[target]
y
# Out:
# 0       56.2
# 1      100.0
# 2       34.3
# 3       26.8
# 4       66.4
#        ...
# 995     76.1
# 996     65.9
# 997     64.4
# 998     69.7
# 999     74.9
# Name: exam_score, Length: 909, dtype: float64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.2)

# %%
X_test
# Out:
#      study_hours_per_day  attendance_percentage  mental_health_rating  \
# 510                  3.1                   71.5                     3
# 316                  3.3                   80.3                     9
# 54                   3.1                   64.0                    10
# 60                   1.7                   92.1                     4
# 287                  4.4                   75.7                     4
# ..                   ...                    ...                   ...
# 356                  5.8                   70.0                     8
# 573                  3.0                   83.6                     3
# 156                  1.9                   71.1                     8
# 138                  3.9                   87.0                     2
# 2                    1.4                   94.8                     1
#
#      sleep_hours
# 510          5.6
# 316          9.7
# 54           7.1
# 60           7.9
# 287          8.8
# ...

# %%
len(X_test)
# Out:
# 728

# %%
len(X_train)
# Out:
# 181

# %%
y_test
# Out:
# 510     51.1
# 316     76.1
# 54      68.1
# 60      61.2
# 287     84.2
#        ...
# 356    100.0
# 573     67.2
# 156     57.7
# 138     64.1
# 2       34.3
# Name: exam_score, Length: 728, dtype: float64

# %%
len(y_test)
# Out:
# 728

# %%
len(y_train)
# Out:
# 181

# %%
# Step 1: Create the model
model = LinearRegression()

# Step 2: Train the model using training data
model.fit(X_train, y_train)

# Step 3: Make predictions on test data
y_pred = model.predict(X_test)

# Step 4: Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R² Score:", r2)
# Out:
# Mean Squared Error: 55.63115687411688
# R² Score: 0.8096591676063856

# %%
y_pred
# Out:
# array([ 56.71682668,  82.06072478,  74.73333156,  52.32738981,
#         79.52306093,  69.92340562,  50.46664754,  55.64061894,
#         37.43109314,  52.93582305,  55.95783379,  62.61896054,
#         84.20841782,  85.9754244 ,  61.13170054,  79.83272349,
#         65.52451124,  53.62162358,  65.30101648,  75.18833552,
#         77.58043194,  87.12187844,  54.7484909 ,  62.05069499,
#         57.5737076 ,  47.32673156,  60.35349831,  58.76415716,
#         97.454507  ,  72.07371072,  62.15654388, 101.82859867,
#         67.03739177, 104.90237302,  66.6809774 ,  61.26670974,
#         95.72705541,  90.94940072,  54.29905513,  85.77615696,
#         85.97309331,  44.80669957,  58.01703098,  59.56260536,
#         73.43319339,  35.87094338,  73.03863995,  75.21782878,
#         73.1165858 ,  67.31915876,  81.1438563 ,  64.6129407 ,
#         44.69213144,  96.82962999,  73.91434806,  85.67052575,
#         44.41427741,  55.34263197,  69.16226079,  77.61349898,
# ...

# %%
import pickle

# %%
pickle.dump(model, open("exam_model.pkl", "wb"))
